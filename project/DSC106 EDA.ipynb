# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
gdp = pd.read_csv('data/gdp.csv')
print(gdp.shape)
gdp.head()
# Out:
# (264, 65)
#   Country Name Country Code     Indicator Name  Indicator Code          1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD           NaN
#
#            1961          1962          1963          1964          1965  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
# ...

# %%
gdp[gdp['Country Name'] == 'United States'].T.iloc[4:-2, :].apply(lambda x: x/100000000).to_csv('data/usa_gdp.csv')

# %%
military = pd.read_csv('data/ms.csv')
military.head()
# Out:
#           Name Code     Type                      Indicator Name  1960  1961  \
# 0        Aruba  ABW  Country  Military expenditure (current USD)   NaN   NaN
# 1  Afghanistan  AFG  Country  Military expenditure (current USD)   NaN   NaN
# 2       Angola  AGO  Country  Military expenditure (current USD)   NaN   NaN
# 3      Albania  ALB  Country  Military expenditure (current USD)   NaN   NaN
# 4      Andorra  AND  Country  Military expenditure (current USD)   NaN   NaN
#
#    1962  1963  1964  1965  ...          2009          2010          2011  \
# 0   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
# 1   NaN   NaN   NaN   NaN  ...  2.518695e+08  2.981469e+08  3.258070e+08
# 2   NaN   NaN   NaN   NaN  ...  3.311193e+09  3.500795e+09  3.639496e+09
# 3   NaN   NaN   NaN   NaN  ...  1.827369e+08  1.858932e+08  1.970068e+08
# 4   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
#
# ...

# %%
military[military.Type == 'Country'][['Name','2018']]
# Out:
# 1       198.086263
# 2      1983.613748
# 3       180.488725
# 7      4144.991771
# 8       608.854650
#           ...
# 255    5500.000000
# 259      63.344074
# 261    3639.879165
# 262     378.025431
# 263     420.364000
# Name: 2018, Length: 151, dtype: float64

# %%
ex = military[military.Type == 'Country'][['Name','2018']]
ex['2018'] = ex['2018'].dropna().apply(lambda x: x/1000000)

# %%
ex.dropna().to_csv('data/mil_exp_2018.csv')

# %%
x.age.plot.hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-20985c997095> in <module>
# ----> 1 x.age.plot.hist()
#
# NameError: name 'x' is not defined

# %%
military
# Out:
#              Name Code     Type                      Indicator Name  \
# 0           Aruba  ABW  Country  Military expenditure (current USD)
# 1     Afghanistan  AFG  Country  Military expenditure (current USD)
# 2          Angola  AGO  Country  Military expenditure (current USD)
# 3         Albania  ALB  Country  Military expenditure (current USD)
# 4         Andorra  AND  Country  Military expenditure (current USD)
# ..            ...  ...      ...                                 ...
# 259        Kosovo  XKX  Country  Military expenditure (current USD)
# 260   Yemen, Rep.  YEM  Country  Military expenditure (current USD)
# 261  South Africa  ZAF  Country  Military expenditure (current USD)
# 262        Zambia  ZMB  Country  Military expenditure (current USD)
# 263      Zimbabwe  ZWE  Country  Military expenditure (current USD)
#
#            1960         1961         1962         1963         1964  \
# 0           NaN          NaN          NaN          NaN          NaN
# ...

# %%
world = military[military['Name'] == 'World'].drop(['Code','Type','Indicator Name'], axis=1).T.dropna()

# %%
world.iloc[1:,:].iloc[:,0].apply(lambda x: x / 1000000000).to_frame().to_csv('world_mil.csv')

# %%
ms_gdp = pd.read_csv('data/ms_gdp.csv')

# %%
ms_gdp[ms_gdp['Country Name'] == 'World'].T.to_csv('ms_world_gdp.csv')

# %%
top = military[military.Type == 'Country'][['Name','2018']].dropna().sort_values('2018',ascending=False).iloc[:5]

# %%
top
# Out:
#               Name          2018
# 249  United States  6.490000e+11
# 38           China  2.500000e+11
# 203   Saudi Arabia  6.755467e+10
# 107          India  6.651029e+10
# 75          France  6.379968e+10

# %%
top['2018'] = top['2018'].apply(lambda x: x / 100000000)

# %%
top.to_csv('data/top_countries.csv')
